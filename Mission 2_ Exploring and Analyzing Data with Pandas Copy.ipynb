# %% [markdown]
# ## Mission 2: Exploring and Analyzing Data with Pandas
#
# Objective:
#
# In this mission, you will perform Exploratory Data Analysis (EDA) and basic data manipulation using Pandas. You will work with a dataset that includes information about employees and apply various data transformation techniques, including handling missing values, filtering, and performing basic data analysis.
#
# Dataset Overview:
#
# The dataset contains the following columns:
#
# employee_id: Unique identifier for each employee.
#
# name: Name of the employee.
#
# age: Age of the employee.
#
# department: The department where the employee works (e.g., HR, Engineering, Marketing).
#
# salary: Annual salary of the employee.
#
# work_experience: Number of years of work experience the employee has.

# %% [markdown]
# ## Task 1: Load the Data
# Objective: Load the dataset into a Pandas DataFrame.
#
# Instructions:
#
# Create a DataFrame from the provided dataset.
#
# Display the first few rows of the dataset to ensure it loaded correctly.

# %%
import pandas as pd

# Create a basic dataset
data = {
    'employee_id': range(1, 21),
    'name': ['John', 'Jane', 'Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack', 'Karen', 'Leo', 'Mia', 'Nina', 'Olivia', 'Paul', 'Quinn', 'Rita'],
    'age': [22, 25, 28, 35, 40, 42, 50, 60, 65, 30, 28, 24, 37, 41, 48, 33, 29, 32, 45, 38],
    'department': ['HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales'],
    'salary': [50000, 60000, 55000, 75000, 80000, 85000, 100000, 110000, 120000, 65000, 67000, 72000, 85000, 90000, 95000, 48000, 67000, 70000, 80000, 88000],
    'work_experience': [1, 3, 5, 7, 10, 12, 15, 18, 20, 3, 1, 6, 4, 8, 5, 7, 3, 2, 6, 5],
}

# Convert the dictionary to a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
display(df)
# Out:
# StatementMeta(, 87471492-76cc-4bb6-b2e3-7b623ab9733f, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a223cb01-e646-4626-a599-2fc981dffb99)

# %%
### To display only the first 5 rows
display(df.head(5))
# Out:
# StatementMeta(, 799dfca1-f8ad-4f3a-b567-dfa85a87b9d9, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, f8cf3060-958e-451f-acf9-6c286bd11a25)

# %% [markdown]
# ### Task 2: Data Exploration
#
# Objective: Explore the dataset to get an understanding of its structure.
#
# Instructions:
#
# Check for missing values in the dataset.
#
# Get the summary statistics of numeric columns (age, salary, work_experience).

# %%
# Check for missing values
missing_values = df.isnull()
display(missing_values)
# Out:
# StatementMeta(, 8a9b4b43-b95f-46cb-bf4e-738f81e72f20, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 3e56054e-9129-471e-bd14-bbba8d5c00f9)

# %%
# Summary statistics for numeric columns
summary_stats = df[['age', 'salary', 'work_experience']].describe()

display(summary_stats)
# Out:
# StatementMeta(, cf85c581-2126-44ff-bd64-b7d984f753d9, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1ddc57b4-48b4-470c-94d4-4595b7c7bd14)

# %% [markdown]
# ### Task 3: Data Transformation
#
# Objective: Perform basic data transformations such as creating new columns and renaming existing ones.
#
# Instructions:
#
# Create a new column called years_to_retirement by subtracting the age from 65.
#
# Rename the salary column to annual_salary.
#
# Sort the DataFrame based on work_experience in descending order.

# %%
## Create a new column called years_to_retirement by subtracting the age from 65

df['years_to_retirement'] = 65 - df['age']
display(df)
# Out:
# StatementMeta(, fcb799ee-697d-4c36-b9e9-1fe1a149e739, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4712dcca-78bc-4706-a00a-d5bae26e930d)

# %%
##Rename the salary column to annual_salary.
df.rename(columns={'salary': 'annual_salary'}, inplace=True)
display(df)
# Out:
# StatementMeta(, 799dfca1-f8ad-4f3a-b567-dfa85a87b9d9, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a439e808-6cc3-4921-87bc-640b90a11f5f)

# %%
##Sort the DataFrame based on work_experience in descending order.
sorted_df = df.sort_values(by='work_experience', ascending=False)
display(sorted_df)
# Out:
# StatementMeta(, 8e182da5-ba63-4011-aa63-c212c290cb68, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 346269ef-dd23-454f-bc90-ab51b0211330)

# %% [markdown]
# ### Task 4: Handling Missing Data
#
# Objective: Handle missing data (if any).
#
# Instructions:
#
# Introduce some missing values in the annual_salary column.
#
# Handle the missing data by either filling it with the mean salary or dropping the rows with missing values.

# %%
import pandas as pd
import numpy as np   

# Example DataFrame
df = pd.DataFrame({
    'id': [9,8,7,6,5],
    'name': ['Grace','Frank','Eve','David','Charlie'],
    'age': [65,60,50,42,40],
    'department': ['Finance','Marketing','Engineering','HR','Sales'],
    'annual_salary': [120000,110000,100000,85000,80000],
    'work_experience': [20,18,15,12,10]
})

# Set a random seed for reproducibility
np.random.seed(42)

# Introduce missing values in ~40% of the annual_salary column
missing_indices = df.sample(frac=0.4).index
df.loc[missing_indices, 'annual_salary'] = np.nan

# Display the DataFrame
display(df)
# Out:
# StatementMeta(, aac85151-17f9-4e9d-96ed-5a4499d0945a, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, a81b6f21-fd22-4a73-a52f-7698d3c79945)

# %%
# Drop rows where salary is missing
df_cleaned = df.dropna(subset=['salary'])
display(df_cleaned)
# Out:
# StatementMeta(, 87cbac4a-b6fc-4df9-95c1-36191ad9a753, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, baf13925-9b92-4ba8-8473-4603f2ffb2a1)

# %% [markdown]
# ## Task 5: Data Filtering and Selection
# Objective: Select specific data based on conditions.
#
# Instructions:
#
# Filter the data to show only employees who are older than 30.
#
# Select only the columns name, age, and annual_salary.

# %%
# Filter the data to show only employees who are older than 30
df_over_30 = df[df['age'] > 30]

# Display the filtered DataFrame
display(df_over_30)
# Out:
# StatementMeta(, e18c7de8-b1c3-4003-a260-75eea113af74, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 79fb8aac-cc25-4c1c-a9b0-c2afd6dea1b3)

# %%
##Select only the columns name, age, and annual_salary.
# Select specific columns
df_selected = df[['name', 'age', 'salary']]

# Display the result
display(df_selected)
# Out:
# StatementMeta(, e18c7de8-b1c3-4003-a260-75eea113af74, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e406e19f-90aa-41b4-be9a-639db907c90b)

# %% [markdown]
# ### Task 6: Data Aggregation
# Objective: Perform group-based aggregation.
#
# Instructions:
#
# Group the data by department and calculate the average salary for each department.

# %%
## Code here
# Group by department and calculate average salary
avg_salary_by_dept = df.groupby('department')['salary'].mean().reset_index()

# Rename the column for clarity
avg_salary_by_dept.rename(columns={'salary': 'average_salary'}, inplace=True)

# Display the result
display(avg_salary_by_dept)
# Out:
# StatementMeta(, 87471492-76cc-4bb6-b2e3-7b623ab9733f, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 490409ce-a7a4-4df9-a33e-b28a37b41f2f)

# %% [markdown]
# Very good, I did not understand much about your process on inserting missing values. However you got the result! Jose A.
